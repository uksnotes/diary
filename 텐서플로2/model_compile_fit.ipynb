# %% [markdown]
# - model.compile() : 학습 과정 정리 loss function 손실 함수 optimizer adam metric accuracy
# - model.fit(x_train, y_train, batch_size = 64, epoch = 3) : 모델에 적용 epoch 반복 횟수 batch_size 64

# %%
import tensorflow as tf
from tensorflow.keras import preprocessing

samples = ['너 오늘 이뻐 보인다',
          '나는 오늘 기분이 더러워',
          '끝내주는데, 좋은 일이 있나봐',
          '나 좋은 일이 생겼어',
          '아 오늘 진짜 짜증나',
          '환상적인데, 정말 좋은거 같아']

labels = [[1],[0],[1],[1],[0],[1]] # 이문장이 긍부정
tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(samples)
sequences = tokenizer.texts_to_sequences(samples)

word_index = tokenizer.word_index

batch_size = 2
num_epochs = 100
vocab_size = len(word_index) + 1 #첫번째부터 print하려고 (0부터 count)
emb_size = 128
hidden_dimension = 256
output_dimension = 1

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(vocab_size, emb_size, input_length = 4))
model.add(tf.keras.layers.Lambda(lambda x: tf.reduce_mean(x, axis = 1)))
model.add(tf.keras.layers.Dense(hidden_dimension, activation = 'relu'))
model.add(tf.keras.layers.Dense(output_dimension, activation = 'sigmoid'))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(sequences, labels, epochs=num_epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 4ms/step - loss: 5.6531e-04 - accuracy: 1.0000
# Epoch 2/100
# 3/3 [==============================] - 0s 5ms/step - loss: 3.3591e-04 - accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9444e-04 - accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2799e-04 - accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 4ms/step - loss: 7.7543e-05 - accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 4ms/step - loss: 5.4829e-05 - accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 4ms/step - loss: 3.8542e-05 - accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7362e-05 - accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 3ms/step - loss: 2.2210e-05 - accuracy: 1.0000
# Epoch 10/100
# ...

# %% [markdown]
# - 지도 학습 : 나이브 베이즈, 의사결정 트리, 서포트 백터 머신
# - 비지도 학습 : 군집화, 가우시안 혼합 모델
# - 평가 모듈 : 교차 검증, 모델 평가
# - 데이터 변환 모듈 : 파이프 라인, 특징 추출, 데이터 전처리, 차원 축소

# %% [markdown]
# ## **pg35**
